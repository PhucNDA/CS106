# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt
# from keras import Sequential
# from collections import deque
# from keras.layers import Dense
# # from keras.optimizers import Adam
# import matplotlib.pyplot as plt
# from keras.activations import relu, linear

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install colabgymrender==1.0.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: colabgymrender==1.0.2 in /usr/local/lib/python3.7/dist-packages (1.0.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (4.1.2.30)
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (0.17.3)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (3.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (0.2.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.3.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.21.6)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.5.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->colabgymrender==1.0.2) (0.16.0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (4.64.0)
# Requirement already satisfied: imageio<3.0,>=2.1.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (2.4.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.1.2->moviepy->colabgymrender==1.0.2) (7.1.2)

# %%
from colabgymrender.recorder import Recorder

# %%
env = gym.make('CartPole-v0')
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0

while not done:
    action = env.action_space.sample()
    next_state, reward, done, info = env.step(action)
    total_reward += reward
    state = next_state

print(total_reward)
env.play()
# Out:
# 15.0
# 100%|██████████| 16/16 [00:00<00:00, 115.86it/s]
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
total_reward
# Out:
# 15.0

# %%
# Hyperparameters
max_epsilon = 1.0
min_epsilon = 0.01
max_num_steps = 50000
epsilon_decay_intervals = 10000
gamma = 0.99 # discount
alpha = 5e-4 # learning rate

memory_size = 50000
min_replay_size = 1000
batch_size = 32

target_update_frequency = 1000 # target network update frequency

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, env):
        super(NeuralNetwork, self).__init__()
    
        self.network = nn.Sequential(
            nn.Linear(env.observation_space.shape[0], 64),
            #nn.ReLU(),
            nn.Tanh(),
            nn.Linear(64, env.action_space.n)
        )
    
    def forward(self, state):
        return self.network(state)
    
    def choose_action(self, state):
        state = torch.tensor(state, dtype=torch.float32)
        q_values = self(state.unsqueeze(0)) # pytorch requires inputs in terms of batch
        best_action = torch.argmax(q_values, dim=1)[0]

        return best_action.detach().item()

# %%
def fill_memory(env):
    memory = deque(maxlen=memory_size)
    state = env.reset()
    for _ in range(min_replay_size):
        action = env.action_space.sample()
        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        state = next_state
        if done:
            env.reset()
    
    return memory

# %%
def dqn_training(env, max_num_steps, max_epsilon, min_epsilon, num_epsilon_decay_intervals, gamma, lr):
    q_net = NeuralNetwork(env)
    target_net = NeuralNetwork(env)
    target_net.load_state_dict(q_net.state_dict())
    optimizer = torch.optim.Adam(q_net.parameters(), lr=lr)

    memory = fill_memory(env)
    reward_buffer = deque(maxlen=100) # Rewards of the previous 100 episodes

    reward_per_episode = 0.0
    state = env.reset()
    all_rewards = []
    for step in range(max_num_steps):
        epsilon = np.interp(step, [0, num_epsilon_decay_intervals], [max_epsilon, min_epsilon])
        #Chọn action dựa vào uniform distribution (0,1)
        random_number = np.random.uniform(0,1)
        if random_number <= epsilon:
            action = env.action_space.sample()
        else:
            action = q_net.choose_action(state)
        #Tương tác với môi trường để xem kết quả nhận về khi tương tác với môi trường là như thế nào
        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        #Lưu experience vào memory
        memory.append(experience)
        #Cập nhận reward
        reward_per_episode += reward
        #Cập nhật đến state tiếp theo
        state = next_state

        #Cập nhật reward_bufer cho mỗi episode hoàn tất và reset lại buffer
        if done:
            state = env.reset()
            reward_buffer.append(reward_per_episode)
            all_rewards.append((step, reward_per_episode))
            reward_per_episode = 0.0

        
        #Lấy một tập minibatch từ experience
        experiences = random.sample(memory, batch_size)
        states = [ex[0] for ex in experiences]
        actions = [ex[1] for ex in experiences]
        rewards = [ex[2] for ex in experiences]
        dones = [ex[3] for ex in experiences]
        next_states = [ex[4] for ex in experiences]

        states = torch.tensor(states, dtype=torch.float32)
        actions = torch.tensor(actions, dtype=torch.int64).unsqueeze(-1) # (batch_size,) --> (batch_size, 1)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(-1)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(-1)
        next_states = torch.tensor(next_states, dtype=torch.float32)

        #Tính targets sử dụng công thức sample = r + gamma * max q(s',a')
        target_q_values = target_net(next_states)
        max_target_q_values = target_q_values.max(dim=1, keepdim=True)[0]
        targets = rewards + gamma * (1-dones) * max_target_q_values

        #Tính hàm loss
        q_values = q_net(states)

        action_q_values = torch.gather(input=q_values, dim=1, index=actions)
        loss = torch.nn.functional.mse_loss(action_q_values, targets)

        #Dùng GD cho q-network
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        #Cập nhật target network
        if (step+1) % target_update_frequency == 0:
            target_net.load_state_dict(q_net.state_dict())

        #Training results
        if (step+1) % 1000 == 0:
            average_reward = np.mean(reward_buffer)
            print(f'Episode: {len(all_rewards)} Step: {step+1} Average reward: {average_reward}')

    return all_rewards, q_net

# %%
all_rewards, q_net = dqn_training(env, max_num_steps, max_epsilon, min_epsilon, epsilon_decay_intervals, gamma, lr=alpha)
# Out:
# Episode: 43 Step: 1000 Average reward: 23.046511627906977
# Episode: 86 Step: 2000 Average reward: 23.08139534883721
# Episode: 127 Step: 3000 Average reward: 23.38
# Episode: 155 Step: 4000 Average reward: 26.91
# Episode: 178 Step: 5000 Average reward: 31.52
# Episode: 201 Step: 6000 Average reward: 35.62
# Episode: 224 Step: 7000 Average reward: 40.56
# Episode: 240 Step: 8000 Average reward: 45.77
# Episode: 250 Step: 9000 Average reward: 51.94
# Episode: 256 Step: 10000 Average reward: 58.25
# Episode: 262 Step: 11000 Average reward: 67.29
# Episode: 267 Step: 12000 Average reward: 74.58
# Episode: 272 Step: 13000 Average reward: 82.58
# Episode: 277 Step: 14000 Average reward: 90.6
# Episode: 282 Step: 15000 Average reward: 98.23
# Episode: 287 Step: 16000 Average reward: 106.49
# Episode: 292 Step: 17000 Average reward: 114.95
# Episode: 297 Step: 18000 Average reward: 122.25
# Episode: 302 Step: 19000 Average reward: 129.79
# Episode: 307 Step: 20000 Average reward: 138.2
# Episode: 312 Step: 21000 Average reward: 145.88
# Episode: 317 Step: 22000 Average reward: 153.84
# Episode: 322 Step: 23000 Average reward: 161.1
# Episode: 327 Step: 24000 Average reward: 168.83
# Episode: 332 Step: 25000 Average reward: 176.34
# Episode: 337 Step: 26000 Average reward: 182.52
# Episode: 342 Step: 27000 Average reward: 188.89
# Episode: 347 Step: 28000 Average reward: 194.15
# Episode: 352 Step: 29000 Average reward: 198.0
# Episode: 357 Step: 30000 Average reward: 199.73
# Episode: 362 Step: 31000 Average reward: 200.0
# Episode: 367 Step: 32000 Average reward: 200.0
# Episode: 372 Step: 33000 Average reward: 200.0
# Episode: 377 Step: 34000 Average reward: 200.0
# Episode: 382 Step: 35000 Average reward: 200.0
# Episode: 387 Step: 36000 Average reward: 200.0
# Episode: 392 Step: 37000 Average reward: 200.0
# Episode: 397 Step: 38000 Average reward: 200.0
# Episode: 402 Step: 39000 Average reward: 200.0
# Episode: 407 Step: 40000 Average reward: 200.0
# Episode: 412 Step: 41000 Average reward: 200.0
# Episode: 417 Step: 42000 Average reward: 200.0
# Episode: 422 Step: 43000 Average reward: 200.0
# Episode: 427 Step: 44000 Average reward: 200.0
# Episode: 432 Step: 45000 Average reward: 200.0
# Episode: 437 Step: 46000 Average reward: 200.0
# Episode: 442 Step: 47000 Average reward: 200.0
# Episode: 447 Step: 48000 Average reward: 200.0
# Episode: 452 Step: 49000 Average reward: 200.0
# Episode: 457 Step: 50000 Average reward: 200.0

# %%
all_rewards = np.array(all_rewards)
plt.xlabel('Steps')
plt.ylabel('Score')
plt.plot(all_rewards[:, 0], all_rewards[:, 1])

# %%
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0
q_net.eval()

with torch.no_grad():
    while not done:
        #action = env.action_space.sample()
        action = q_net.choose_action(state)
        next_state, reward, done, info = env.step(action)
        total_reward += reward
        state = next_state

print(total_reward)
env.play()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9bcc9142edd1> in <module>()
#       3 done = False
#       4 total_reward = 0.0
# ----> 5 q_net.eval()
#       6
#       7 with torch.no_grad():
#
# NameError: name 'q_net' is not defined

# %% [markdown]
# #Xây dựng mạng NN cho bài toán Moutain Car

# %%
#Tạo biến môi trường
env = gym.make('MountainCar-v0')
env.reset()

#Lấy state hiện tại sau khởi tạo
print(env.state)
# Out:
# [-0.57710407  0.        ]

# %% [markdown]
# State được cấu thành bởi coor của x-axis và vận tốc tại đó

# %%
#Kích thước không gian mà state có thể thực hiện 
print(env.action_space.n)
# Out:
# 3

# %% [markdown]
# State bao gồm các bước đi qua trái, đứng yên và đi qua phải

# %%
#Lấy vị trí, vận tốc tối thiểu và tối đa của environment đó
print(env.observation_space.low)
print(env.observation_space.high)
### Đi từ -1.2->0.6 với vận tốc tương ứng -0.07->0.07
# Out:
# [-1.2  -0.07]
# [0.6  0.07]

# %%
# Hyperparameters
max_epsilon = 1.0
min_epsilon = 0.01
max_num_steps = 500000
epsilon_decay_intervals = 10000
gamma = 0.95 # discount
alpha = 0.001 # learning rate

memory_size = 100000
min_replay_size = 1000
batch_size = 256

target_update_frequency = 1000 # target network update frequency

# %%
class NeuralNetwork1(nn.Module):
    def __init__(self, env):
        super(NeuralNetwork1, self).__init__()
    
        self.network = nn.Sequential(
            nn.Linear(env.observation_space.shape[0], 50),
            nn.ReLU(),
            nn.Linear(50, 25),
            nn.ReLU(),
            nn.Linear(25, env.action_space.n)
            # #nn.ReLU(),
            # nn.Tanh(),
            # nn.Linear(64, env.action_space.n)
        )
        # self.network.add_module(Dense(20, input_dim=env.observation_space.shape[0], activation=relu))
        # self.network.add_module(Dense(25, activation=relu))
        # self.network.add_module(Dense(env.action_space.n, activation=linear))
    
    def forward(self, state):
        return self.network(state)
    
    def choose_action(self, state):
        state = torch.tensor(state, dtype=torch.float32)
        q_values = self(state.unsqueeze(0)) # pytorch requires inputs in terms of batch
        best_action = torch.argmax(q_values, dim=1)[0]

        return best_action.detach().item()

# %%
def dqn_training1(env, max_num_steps, max_epsilon, min_epsilon, num_epsilon_decay_intervals, gamma, lr):
    q_net = NeuralNetwork1(env)
    target_net = NeuralNetwork1(env)
    target_net.load_state_dict(q_net.state_dict())
    optimizer = torch.optim.Adam(q_net.parameters(), lr=lr)

    memory = fill_memory(env)
    reward_buffer = deque(maxlen=100) # Rewards of the previous 100 episodes

    reward_per_episode = 0.0
    state = env.reset()
    all_rewards = []
    for step in range(max_num_steps):
        epsilon = np.interp(step, [0, num_epsilon_decay_intervals], [max_epsilon, min_epsilon])
        #Chọn action dựa vào uniform distribution (0,1)
        random_number = np.random.uniform(0,1)
        if random_number <= epsilon:
            action = env.action_space.sample()
        else:
            action = q_net.choose_action(state)
        #Tương tác với môi trường để xem kết quả nhận về khi tương tác với môi trường là như thế nào
        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        #Lưu experience vào memory
        memory.append(experience)
        #Cập nhận reward
        reward_per_episode += reward
        #Cập nhật đến state tiếp theo
        state = next_state

        #Cập nhật reward_bufer cho mỗi episode hoàn tất và reset lại buffer
        if done:
            state = env.reset()
            reward_buffer.append(reward_per_episode)
            all_rewards.append((step, reward_per_episode))
            reward_per_episode = 0.0

        
        #Lấy một tập minibatch từ experience
        experiences = random.sample(memory, batch_size)
        states = [ex[0] for ex in experiences]
        actions = [ex[1] for ex in experiences]
        rewards = [ex[2] for ex in experiences]
        dones = [ex[3] for ex in experiences]
        next_states = [ex[4] for ex in experiences]

        states = torch.tensor(states, dtype=torch.float32)
        actions = torch.tensor(actions, dtype=torch.int64).unsqueeze(-1) # (batch_size,) --> (batch_size, 1)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(-1)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(-1)
        next_states = torch.tensor(next_states, dtype=torch.float32)

        #Tính targets sử dụng công thức sample = r + gamma * max q(s',a')
        target_q_values = target_net(next_states)
        max_target_q_values = target_q_values.max(dim=1, keepdim=True)[0]
        targets = rewards + gamma * (1-dones) * max_target_q_values

        #Tính hàm loss
        q_values = q_net(states)

        action_q_values = torch.gather(input=q_values, dim=1, index=actions)
        loss = torch.nn.functional.mse_loss(action_q_values, targets)

        #Dùng GD cho q-network
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        #Cập nhật target network
        if (step+1) % target_update_frequency == 0:
            target_net.load_state_dict(q_net.state_dict())

        #Training results
        if (step+1) % 1000 == 0:
            average_reward = np.mean(reward_buffer)
            print(f'Episode: {len(all_rewards)} Step: {step+1} Average reward: {average_reward}')

    return all_rewards, q_net

# %%
all_rewards,  q_net = dqn_training1(env, max_num_steps, max_epsilon, min_epsilon, epsilon_decay_intervals, gamma, lr=alpha)
print(all_rewards)
# Out:
# Episode: 5 Step: 1000 Average reward: -200.0
# Episode: 10 Step: 2000 Average reward: -200.0
# Episode: 15 Step: 3000 Average reward: -200.0
# Episode: 20 Step: 4000 Average reward: -200.0
# Episode: 25 Step: 5000 Average reward: -200.0
# Episode: 30 Step: 6000 Average reward: -200.0
# Episode: 35 Step: 7000 Average reward: -200.0
# Episode: 40 Step: 8000 Average reward: -200.0
# Episode: 45 Step: 9000 Average reward: -200.0
# Episode: 50 Step: 10000 Average reward: -200.0
# Episode: 55 Step: 11000 Average reward: -200.0
# Episode: 60 Step: 12000 Average reward: -200.0
# Episode: 65 Step: 13000 Average reward: -200.0
# Episode: 70 Step: 14000 Average reward: -200.0
# Episode: 75 Step: 15000 Average reward: -200.0
# Episode: 80 Step: 16000 Average reward: -199.8
# Episode: 85 Step: 17000 Average reward: -199.81176470588235
# Episode: 90 Step: 18000 Average reward: -199.82222222222222
# Episode: 95 Step: 19000 Average reward: -199.83157894736843
# Episode: 100 Step: 20000 Average reward: -199.84
# Episode: 105 Step: 21000 Average reward: -199.56
# Episode: 110 Step: 22000 Average reward: -199.29
# Episode: 115 Step: 23000 Average reward: -199.29
# Episode: 120 Step: 24000 Average reward: -199.14
# Episode: 125 Step: 25000 Average reward: -199.14
# Episode: 130 Step: 26000 Average reward: -198.73
# Episode: 135 Step: 27000 Average reward: -198.15
# Episode: 141 Step: 28000 Average reward: -197.74
# Episode: 146 Step: 29000 Average reward: -197.02
# Episode: 152 Step: 30000 Average reward: -194.64
# Episode: 157 Step: 31000 Average reward: -194.06
# Episode: 163 Step: 32000 Average reward: -192.22
# Episode: 169 Step: 33000 Average reward: -190.19
